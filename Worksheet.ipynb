# %%
#   Steps
#1  Create Dictionary based tree
import witcher_school_of_python

# %%
import pandas as pd
from witcher_school_of_python import *

# %%
import numpy
df = questgetter.loadQuests("source\Quest.csv")
if df.loc[df["ID"] == numpy.int64(180)]["ID"].item() == numpy.int64(180):
    print("bro???")
# Out:
# bro???

# %%
#from treeset import TreeSet
newtree = ts.TreeSet(df)
# Can only compare identically-labeled Series objects ???
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-ea2e61a07412> in <module>
#       1 #from treeset import TreeSet
# ----> 2 newtree = ts.TreeSet(df)
#
# c:\Users\HP\Desktop\Pythoon2\Witcher3\witcher_school_of_python\TreeSet.py in __init__(self, dataframe)
#      30         self.Tree = []
#      31         for i,r in dataframe.iterrows():
# ---> 32             if r[4] == "Main":
#      33                 self.Tree.append(Node(dataframe, r[0]))
#      34             else:
#
# c:\Users\HP\Desktop\Pythoon2\Witcher3\witcher_school_of_python\TreeSet.py in __init__(self, dataframe, ID)
#       4 class Node:
#       5     def __init__(self, dataframe, ID):
# ----> 6         ID = dataframe.loc[dataframe["ID"].item() == np.int64(ID)]["ID"]
#       7         Name = dataframe.loc[dataframe["ID"].item() == np.int64(ID)]["Quest"]
#       8         if self.ID == 304:
#
# ...
